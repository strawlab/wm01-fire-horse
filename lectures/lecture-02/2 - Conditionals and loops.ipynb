# %% [markdown]
# # Conditionals and loops
#
# So far our programs have run straight through, top to bottom. **Control flow**
# lets a program make decisions and repeat work. We start with the `bool` type
# and comparisons, then `if`/`elif`/`else`, `assert` for checking our
# assumptions, and finally `while` loops.

# %% [markdown]
# # Boolean (`bool`) type
#
# Python's `bool` type can take one of two values: `True` or `False`. It is used to test a condition, such as in an *if statement*.

# %%
x = 1
y = x > 0
y

# %%
type(y)

# %%
x = 1

if x > 0:
    print("x is positive")
    x = 10

x

# %%
x = -1

if x > 0:
    y = 20
    print("x is positive")
    print("x is still positive")
else:
    y = 40
    print("x is negative")
    print("x is still negative")
    
print("out of the blocks")
print(y)

# %% [markdown]
# # Equality and comparisons
#
# Comparison operators: `==`, `>`, `>=`, `<`, `<=`, `!=`
#
# These operators take two arguments (left and right hand side) and return a boolean.

# %%
3 > 4

# %%
3 == 4

# %%
2+2 == 4

# %% [markdown]
# ## Nested blocks and `elif`

# %%
if True:
    print("statement 1")
    print("statement 2")
    print("statement 3")

# %%
a = 1
b = -2

if a==1:
    if b>0:
        print("a is one and b is positive")
    else:
        print("here")
        print("a is one")
else:
    print("a is not one")

# %%
a = 1
b = -1.0

if a==1:
    if b>0:
        print("a is one and b is positive")
    elif b<0:
        print("a is one and b is negative")
    else:
        print("a is one")
        print("b is zero")
else:
    print("a is not one")

# %% [markdown]
# ## Checking your assumptions with `assert`
#
# `assert` checks that a condition is `True`. If it is, nothing happens; if it is
# `False`, Python raises an `AssertionError`. This is a cheap, powerful way to
# catch mistakes early and to document what your code expects. We will use
# `assert` throughout the course to test small examples.

# %%
assert True

# %%
assert False

# %%
assert 2 + 2 == 4

# %%
assert 1 + 1 == 3

# %%
assert 1 + 1 == 3, "This is the error message"

# %%
def my_cool_function(a,b):
    assert type(a)==list
    assert type(b)==list
    a.append(10)
    b.append(20)

# %%
x = [1,2,3]
y = [4,4,5]
my_cool_function( x, y)

# %%
x

# %%
y

# %%
my_cool_function(1,2)

# %% [markdown]
# # Control flow with `while`

# %%
x = True
y = 0
while x:
    print(y)
    y = y + 100
    if y >= 1000:
        x = False
print('done')

# %%
y = 0
while True:
    print(y)
    y = y + 100
    if y >= 1000:
        break
print('done')

# %%
y = 0
while y < 1000:
    print(y)
    y = y + 100
print('done')

# %% [markdown]
# ## `break` and `continue`

# %%
y = 0
while True:
    print(y)
    y = y + 100
    if y >= 1000:
        break

# %%
y = 0
while True:
    print(y)    
    y = y + 100
    if y >= 1000:
        break
    if y < 400:
        continue    
    y = y + 10

# %%
y

# %% [markdown]
# ## The `+=` (and `-=`, `*=`, .. ) operator.

# %%
y += 20

# %%
y

# %%
y = y +20

# %%
y

# %%
y -= 20

# %%
y

# %%
y*= 1.1

# %%
y

# %%
y = 0
while y < 1000:
    print(y)
    y += 100
print('done')
