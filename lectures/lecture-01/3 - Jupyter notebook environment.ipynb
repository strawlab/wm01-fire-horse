# %% [markdown]
# ## The Jupyter notebook environment (formerly IPython notebooks)
#
# Articles:
#
# - https://www.dataquest.io/blog/jupyter-notebook-tutorial/

# %% [markdown]
# ## Jupyter notebooks let you execute Python code in a browser.
#
# They have advantages and disadvantages compared to other ways of running
# Python code. We will start with them in this class to rapidly get programming.
#
# In this course, we use [Sunbeam](https://github.com/strawlab/sunbeam) to
# launch Jupyter Lab with Python already set up on your own computer.

# %%
# this is a comment
2+2

# %%
a = 4

# %% [markdown]
# The result of the last line is displayed in the notebook environment.

# %%
a

# %%
a = 5

# %%
a

# %% [markdown]
# ## Good practice
#
# It is good practice to "Kernel -> restart and run all" prior to finishing work on a Jupyter notebook.
#
# In this course, we are also using the `nbgrader` Jupyter extension. This adds a `Validate` button at the top of the window which re-runs the notebook.

# %%
# This is an nbgrader automatic test.

assert a==5

# %% [markdown]
# If you do not see the "Validate" button above, `nbgrader` may not be
# installed in your environment. If necessary, install it in a terminal with
# `uv add nbgrader` (or ask an instructor for help).

# %% [markdown]
# ## Jupyter Lab
